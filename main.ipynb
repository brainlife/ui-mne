# %%
import os
import mne

#find fif images
import glob
#there could be multiple if we stage other data previously..
#TODO - use INPUT_DIR env
fif = glob.glob("/input-instance/*/*/meg.fif")[0] 

raw = mne.io.read_raw_fif(fif)
raw.crop(tmax=60).load_data()
# Out:
# Opening raw data file /input-instance/606357e59cbea66f3660ef21/600f5aaa4c6096530d1466d3/meg.fif...
#     Read a total of 8 projection items:
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#         generated with autossp-1.0.1 (1 x 306)  idle
#     Range : 165000 ... 527999 =     55.000 ...   176.000 secs
# Ready.
# Reading 0 ... 180000  =      0.000 ...    60.000 secs...
# ...

# %%
raw.plot()
# Out:
# <MNEBrowseFigure size 432x288 with 5 Axes>
# <MNEBrowseFigure size 432x288 with 5 Axes>
